# %%
# !pip install sentence-transformers
# !pip install faiss-cpu
# !pip install psycopg2-binary
# !pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 60.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import faiss

from collections import Counter

from sentence_transformers import (
SentenceTransformer
)

from sqlalchemy import (
create_engine
)

# %%
df = pd.read_csv(
    "cleaned_dataset.csv"
)

index = faiss.read_index(
    "capa_index.faiss"
)

model = SentenceTransformer(
    "all-MiniLM-L6-v2"
)

print("Retrieval assets loaded")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
capa_df = pd.read_csv(
    "historical_capa_records.csv"
)

print(capa_df.shape)

capa_df.head()
# Out:
# (1000, 23)
#           capa_id   open_date  close_date  days_to_close  \
# 0  CAPA-2022-0001  2022-09-15  2023-01-12            119
# 1  CAPA-2020-0002  2020-12-19  2021-04-21            123
# 2  CAPA-2019-0003  2019-02-18  2019-06-09            111
# 3  CAPA-2018-0004  2018-08-18  2018-12-05            109
# 4  CAPA-2022-0005  2022-06-24  2022-09-16             84
#
#                               product     department severity  \
# 0          Amoxicillin 500mg Capsules      Packaging     High
# 1  Morphine Sulfate 10mg/mL Injection  QC Laboratory   Medium
# 2                Warfarin 5mg Tablets  QC Laboratory     High
# 3            Heparin Sodium 5000IU/mL      Warehouse   Medium
# 4           Paracetamol 500mg Tablets      Packaging     High
#
#                       root_cause regulatory_reference  \
# 0  Environmental Control Failure  21 CFR Part 211.130
# 1            Documentation Error           USP <1058>
# 2              Process Deviation  21 CFR Part 211.192
# ...

# %%
new_incident = (
"Unexpected HVAC failure caused environmental monitoring deviation."
)

# %%
query_embedding = model.encode(
    [new_incident]
)

# %%
k = 5

distances, indices = index.search(

    np.array(
        query_embedding
    ).astype(
        "float32"
    ),

    k

)

print(indices)
# Out:
# [[  85 1468 1538 1191  951]]

# %%
retrieved=[]

for i in indices[0]:

    row=df.iloc[i]

    retrieved.append({

        "incident":
        row["incident_description"],

        "root_cause":
        row["root_cause"],

        "severity":
        row["severity_level"]

    })

retrieved_df=pd.DataFrame(
retrieved
)

retrieved_df
# Out:
#                                             incident  \
# 0  HVAC system failure in cleanroom Room B202 res...
# 1  HVAC system failure in cleanroom Room B202 res...
# 2  HVAC system failure in cleanroom Room B202 res...
# 3  HVAC system failure in cleanroom Room D104 res...
# 4  HVAC system failure in cleanroom Room A101 res...
#
#                       root_cause severity
# 0  Environmental Control Failure   Medium
# 1  Environmental Control Failure     High
# 2  Environmental Control Failure      Low
# 3  Environmental Control Failure     High
# 4  Environmental Control Failure     High

# %%
from collections import Counter

root_cause = Counter(
    retrieved_df["root_cause"]
).most_common(1)[0][0]

severity = Counter(
    retrieved_df["severity"]
).most_common(1)[0][0]

print("Root Cause:", root_cause)
print("Severity:", severity)
# Out:
# Root Cause: Environmental Control Failure
# Severity: High

# %%
recommendations = capa_df[

    (capa_df["root_cause"] == root_cause)

    &

    (capa_df["severity"] == severity)

]

print(
recommendations.shape
)

recommendations.head()
# Out:
# (81, 23)
#            capa_id   open_date  close_date  days_to_close  \
# 0   CAPA-2022-0001  2022-09-15  2023-01-12            119
# 14  CAPA-2020-0015  2020-10-05  2021-01-23            110
# 33  CAPA-2019-0034  2019-03-19  2019-07-22            125
# 44  CAPA-2023-0045  2023-04-04  2023-08-16            134
# 46  CAPA-2019-0047  2019-01-09  2019-04-30            111
#
#                                  product     department severity  \
# 0             Amoxicillin 500mg Capsules      Packaging     High
# 14  Vancomycin 500mg Powder for Infusion   Sterile Fill     High
# 33    Morphine Sulfate 10mg/mL Injection  Manufacturing     High
# 44            Amoxicillin 500mg Capsules   Sterile Fill     High
# 46       Enoxaparin 40mg/0.4mL Injection      Packaging     High
#
#                        root_cause regulatory_reference  \
# 0   Environmental Control Failure  21 CFR Part 211.130
# 14  Environmental Control Failure  21 CFR Part 211.113
# ...

# %%
corrective_actions = (

recommendations[
"corrective_action"

]

.dropna()

.tolist()

)

preventive_actions = (

recommendations[
"preventive_action"

]

.dropna()

.tolist()

)

# %%
corr_rank = Counter(
corrective_actions
)

prev_rank = Counter(
preventive_actions
)

# %%
print(
"\n===== CAPA RECOMMENDATIONS ====="
)

print(
"\nCorrective Actions:"
)

for action,count in (

corr_rank
.most_common(3)

):

    print(
f"- {action}"
)

print(
"\nPreventive Actions:"
)

for action,count in (

prev_rank
.most_common(3)

):

    print(
f"- {action}"
)
# Out:
# ===== CAPA RECOMMENDATIONS =====
#
# Corrective Actions:
# - Filling halted. HEPA filter replaced. DOP test passed on replacement filter. Batch risk-assessed — sterility test initiated. Grade A re-qualified before restart.
# - Dispensed materials quarantined and tested for conformance against stability data. AC unit repaired. Materials released after QA review of stability data.
# - Fill area taken out of service. Full decontamination with sporicidal agent. Filter replaced. Grade A re-qualified over 3 consecutive days. Batch quarantined for sterility testing.
#
# Preventive Actions:
# - HEPA filter replacement scheduled at 10 months (not 12) to provide buffer. DOP test added to quarterly PM rather than annual. Filter age tracked in LIMS with auto-alert 60 days before due.
# - Continuous temperature monitoring with alarm to QA office and engineering installed in all dispensary areas. AC unit added to monthly PM schedule. Backup portable AC unit available for emergency deployment.
# ...

# %% [markdown]
# Similar Historical Cases Count

# %%
historical_cases = len(
recommendations
)

print(
"Historical Similar Cases:",
historical_cases
)
# Out:
# Historical Similar Cases: 81

# %% [markdown]
# Recommendation Confidence

# %%
from collections import Counter
import numpy as np


# ----------------------------------
# 1. ROOT CAUSE
# ----------------------------------

root_cause = Counter(
    retrieved_df["root_cause"]
).most_common(1)[0][0]


# ----------------------------------
# 2. SEVERITY
# ----------------------------------

severity = Counter(
    retrieved_df["severity"]
).most_common(1)[0][0]


# ----------------------------------
# 3. CONFIDENCE SCORE
# ----------------------------------


top_distance = float(
distances[0][0]
)

confidence = float(

round(

100*np.exp(
-top_distance
/

(
float(
np.max(
distances
)
)

+1e-10

)

),

2

)

)

# ----------------------------------
# 4. SEARCH HISTORICAL CAPAs
# ----------------------------------

recommendations = capa_df[

(capa_df["root_cause"]==root_cause)

&

(capa_df["severity"]==severity)

]


# ----------------------------------
# 5. HISTORICAL CASE COUNT
# ----------------------------------

historical_cases = len(
recommendations
)


# ----------------------------------
# 6. EXTRACT ACTIONS
# ----------------------------------

corrective_actions = (

recommendations[
"corrective_action"

]

.dropna()

.tolist()

)

preventive_actions = (

recommendations[
"preventive_action"

]

.dropna()

.tolist()

)


# ----------------------------------
# 7. RANK ACTIONS
# ----------------------------------

corr_rank = Counter(
corrective_actions
)

prev_rank = Counter(
preventive_actions
)


# ----------------------------------
# 8. RECOMMENDATION REASON
# ----------------------------------

reason = f"""

Generated using:

• Similar historical incidents

• Root Cause:
{root_cause}

• Severity:
{severity}

• Historical CAPAs:
{historical_cases}

"""


# ----------------------------------
# FINAL OUTPUT
# ----------------------------------

print(
"\n===== CAPA RECOMMENDATION ====="
)

print(
f"""

Most Likely Root Cause:

{root_cause}

"""
)


print(
f"""

Estimated Severity:

{severity}

"""
)


print(
f"""

Confidence:

{confidence:2f}%

"""
)


print(
f"""

Historical Similar Cases:

{historical_cases}

"""
)


print(
"\nCorrective Actions:"
)

for action,count in (

corr_rank
.most_common(3)

):

    print(
f"- {action}"
)



print(
"\nPreventive Actions:"
)

for action,count in (

prev_rank
.most_common(3)

):

    print(
f"- {action}"
)



print(
"\nRecommendation Reason:"
)

print(
reason
)
# Out:
# ===== CAPA RECOMMENDATION =====
#
#
# Most Likely Root Cause:
#
# Environmental Control Failure
#
#
#
#
# Estimated Severity:
#
# High
#
#
#
#
# Confidence:
#
# 37.370000%
#
#
#
#
# Historical Similar Cases:
#
# 81
#
#
#
# Corrective Actions:
# - Filling halted. HEPA filter replaced. DOP test passed on replacement filter. Batch risk-assessed — sterility test initiated. Grade A re-qualified before restart.
# - Dispensed materials quarantined and tested for conformance against stability data. AC unit repaired. Materials released after QA review of stability data.
# - Fill area taken out of service. Full decontamination with sporicidal agent. Filter replaced. Grade A re-qualified over 3 consecutive days. Batch quarantined for sterility testing.
#
# Preventive Actions:
# - HEPA filter replacement scheduled at 10 months (not 12) to provide buffer. DOP test added to quarterly PM rather than annual. Filter age tracked in LIMS with auto-alert 60 days before due.
# ...

# %%
print(
"\n===== WHY THIS RECOMMENDATION ====="
)

print(
f"""

Top Similar Incident:

{retrieved_df.iloc[0]["incident"]}

"""
)

print(
f"""

Root Cause Match:

{root_cause}

"""
)

print(
f"""

Severity Match:

{severity}

"""
)

print(
f"""

Historical CAPAs Used:

{historical_cases}

"""
)

print(
f"""

Confidence:

{confidence}%

"""
)
# Out:
# ===== WHY THIS RECOMMENDATION =====
#
#
# Top Similar Incident:
#
# HVAC system failure in cleanroom Room B202 resulted in differential pressure drop below specification. Grade integrity compromised for 6.3 hours during batch C9880A manufacture.
#
#
#
#
# Root Cause Match:
#
# Environmental Control Failure
#
#
#
#
# Severity Match:
#
# High
#
#
#
#
# Historical CAPAs Used:
#
# 81
#
#
#
#
# Confidence:
#
# 0%
